# %% [markdown]
# This notebook is used to compare the data collected from the API with the data collected from the scraper.

# %%
import pandas as pd

# %%
scraper_df = pd.read_csv(r"..\data\raw\archive\AnimeData_300724.csv")
scraper_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26794 entries, 0 to 26793
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         26794 non-null  object
#  1   Episodes      13552 non-null  float64
#  2   Release Year  26794 non-null  int64
#  3   Status        26389 non-null  object
#  4   Genres        21414 non-null  object
#  5   Studio        25663 non-null  object
#  6   Source        23896 non-null  object
#  7   Demographic   10142 non-null  object
#  8   Themes        0 non-null      float64
#  9   Synopsis      26785 non-null  object
#  10  Voters        13078 non-null  float64
#  11  Rating        646 non-null    float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
api_df = pd.read_csv(r"..\data\raw\anime_master_db.csv")
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mal_id          500 non-null    int64
#  1   Title           500 non-null    object
#  2   English Title   484 non-null    object
#  3   Japanese Title  500 non-null    object
#  4   Episodes        499 non-null    float64
#  5   Release Year    500 non-null    int64
#  6   Status          500 non-null    object
#  7   Air Date        500 non-null    object
#  8   Genres          500 non-null    object
#  9   Themes          428 non-null    object
#  10  Demographics    244 non-null    object
#  11  Studio          500 non-null    object
#  12  Producers       495 non-null    object
#  13  Synopsis        500 non-null    object
#  14  Rating          500 non-null    float64
#  15  Voters          500 non-null    int64
#  16  Popularity      500 non-null    int64
# ...

# %%
api_df
# Out:
#      mal_id                                              Title  \
# 0     16498                                 Shingeki no Kyojin
# 1      1535                                         Death Note
# 2      5114                   Fullmetal Alchemist: Brotherhood
# 3     30276                                      One Punch Man
# 4     38000                                   Kimetsu no Yaiba
# ..      ...                                                ...
# 495   51180  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...
# 496   34662                                     Fate/Apocrypha
# 497   31181                                    Owarimonogatari
# 498   36038                                  Net-juu no Susume
# 499   31758                   Kizumonogatari III: Reiketsu-hen
#
#                            English Title              Japanese Title  \
# 0                        Attack on Titan                       進撃の巨人
# ...
