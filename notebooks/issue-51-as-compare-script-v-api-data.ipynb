# %% [markdown]
# This notebook is used to compare the data collected from the API with the data collected from the scraper.

# %%
import pandas as pd

# %%
scraper_df = pd.read_csv("../data/raw/archive/AnimeData_300724.csv")
scraper_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26794 entries, 0 to 26793
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         26794 non-null  object
#  1   Episodes      13552 non-null  float64
#  2   Release Year  26794 non-null  int64
#  3   Status        26389 non-null  object
#  4   Genres        21414 non-null  object
#  5   Studio        25663 non-null  object
#  6   Source        23896 non-null  object
#  7   Demographic   10142 non-null  object
#  8   Themes        0 non-null      float64
#  9   Synopsis      26785 non-null  object
#  10  Voters        13078 non-null  float64
#  11  Rating        646 non-null    float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
api_df = pd.read_csv("../data/raw/anime_master_db.csv")
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mal_id          5000 non-null   int64
#  1   Title           5000 non-null   object
#  2   English Title   4224 non-null   object
#  3   Japanese Title  4998 non-null   object
#  4   Episodes        4912 non-null   float64
#  5   Release Year    4961 non-null   float64
#  6   Status          5000 non-null   object
#  7   Air Date        5000 non-null   object
#  8   Genres          4953 non-null   object
#  9   Themes          3891 non-null   object
#  10  Demographics    2069 non-null   object
#  11  Studio          4948 non-null   object
#  12  Producers       4239 non-null   object
#  13  Synopsis        4993 non-null   object
#  14  Rating          4910 non-null   float64
#  15  Voters          4910 non-null   float64
#  16  Popularity      5000 non-null   int64
# ...

# %%
api_df.head(2)
# Out:
#    mal_id               Title    English Title Japanese Title  Episodes  \
# 0   16498  Shingeki no Kyojin  Attack on Titan          進撃の巨人      25.0
# 1    1535          Death Note       Death Note          デスノート      37.0
#
#    Release Year           Status                     Air Date  \
# 0        2013.0  Finished Airing  Apr 7, 2013 to Sep 29, 2013
# 1        2006.0  Finished Airing  Oct 4, 2006 to Jun 27, 2007
#
#                                    Genres                    Themes  ...  \
# 0  Action, Award Winning, Drama, Suspense  Gore, Military, Survival  ...
# 1                  Supernatural, Suspense             Psychological  ...
#
#       Voters Popularity   Rank  Members  Favorites  \
# 0  3026735.0          1  120.0  4298745     186403
# 1  2966541.0          2   97.0  4239320     184072
#
#                    Content Rating  Source       Duration  \
# 0  R - 17+ (violence & profanity)   Manga  24 min per ep
# 1  R - 17+ (violence & profanity)   Manga  23 min per ep
#
# ...
